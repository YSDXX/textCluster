# %%
import os
import jieba as jb
import numpy as np
import pandas as pd

# %%
fileName = "1月1日-12月17日上报网公司周报工单详情.xlsx"
cwd = os.getcwd() # get current diretory
filePath = os.path.join(cwd,fileName)

df = pd.read_excel(filePath)

# %%
df["需求描述"]
# Out:
# 0        天河供电局郭满杭报忘记了南网GIS的密码，申请重置密码。\r\n联系电话：25073\135...
# 1          信息公司陈康梅咨询南网gis工单无法查询工作票交底单号\r\n联系电话：13512792322
# 2        海珠局配电部童锐报在南网GIS系统从B/S端登入预定义查询设备数量情况需要进行统计，发现数据...
# 3          18f计划部方兵华报南网gis无法显示低压线路沿步图。电话：23499、15920475521
# 4        番禺局营销部冼志毅、田博宇申请南网GIS系统-BS端查询变压器设备参数权限。\r\n联系电话...
# 5        白云供电局张国樑报4A无法跳转到B/S GIS上，提示需要输入用户名和密码。\r\n联系电话...
# 6        白云供电局冯金松报南网GIS-其他类型工单2017010309172801810071668...
# 7                      越秀局张晏玉报在4A里没有南网GIS图标。\r\n联系电话：20174
# 8         白云供电局周才权报南网GIS设备运维单位无法选择广州局。\r\n联系电话：15902035072
# 9                     海珠局台区班简柏杰报南网gis打开提示5字头的错误代码。电话：20549
# 10       南沙局旧镇配电部运行二班章世佳咨询需要后台协助安装南网GIS客户端。\r\n联系电话：399...
# 11       增城新塘所 陈永辉报新安装的南网GIS客户端用4A账号密码登陆提示不对应（76058/135...
# 12       白云局梁叶彬代汪婷婷、黄凯怡、谭浩汉、梁叶彬申请南网GIS查询权限。请看附件。\r\n联系电...
# 13       白云供电局西郊花刘启华报南网配电gis有部门功能无法打开。电话：86416087、13286...
# 14       白云局西郊所黄荣诺，黄耀峰申请南网GIS系统权限，工作需要使用新GIS查线，查故障，详细看附...
# 15       南沙供电局李汉跃咨询南网GIS系统无法打开，提示文件缺失。\r\n联系电话：13430387044
# ...

# %%
df["系统名称"][0:3]
# Out:
# 0    GIS平台(南网)
# 1    GIS平台(南网)
# 2    GIS平台(南网)
# Name: 系统名称, dtype: object

# %%
df["需求类型"][0:3]
# Out:
# 0    咨询
# 1    咨询
# 2    咨询
# Name: 需求类型, dtype: object
